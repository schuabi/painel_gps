# %%
import pandas as pd

# %%
# Exemplo: Carregando seu DataFrame
df = pd.read_csv('programacao_partidas.csv', sep=';')  # Altere o nome do arquivo conforme o seu caso

# %%
df
# Out:
#      Linha  Viagens Programadas Tipo Linha  Tipo Dia Tipo de Programação  \
# 0      100                    0      Linha  Dia Útil           100% SMTR
# 1      105                    0      Linha  Dia Útil           100% SMTR
# 2      108                    0      Linha  Dia Útil           100% SMTR
# 3      110                    0      Linha  Dia Útil           100% SMTR
# 4      112                    0      Linha  Dia Útil           100% SMTR
# ..     ...                  ...        ...       ...                 ...
# 219  SN538                    5      Linha  Dia Útil           100% SMTR
# 220  SP309                    0    Serviço  Dia Útil           100% SMTR
# 221  SP315                    0    Serviço  Dia Útil           100% SMTR
# 222  SP553                    0    Serviço  Dia Útil           100% SMTR
# 223  SV112                    4      Linha  Dia Útil           100% SMTR
#
#      Faixa
# 0    00-03
# 1    00-03
# 2    00-03
# 3    00-03
# 4    00-03
# ..     ...
# ...

# %%
df['Tipo Dia'] = df['Tipo Dia'].replace('Dia Útil', 'Facultativo')

# %%
df
# Out:
#      Linha  Viagens Programadas Tipo Linha     Tipo Dia Tipo de Programação  \
# 0      100                    0      Linha  Facultativo           100% SMTR
# 1      105                    0      Linha  Facultativo           100% SMTR
# 2      108                    0      Linha  Facultativo           100% SMTR
# 3      110                    0      Linha  Facultativo           100% SMTR
# 4      112                    0      Linha  Facultativo           100% SMTR
# ..     ...                  ...        ...          ...                 ...
# 219  SN538                    5      Linha  Facultativo           100% SMTR
# 220  SP309                    0    Serviço  Facultativo           100% SMTR
# 221  SP315                    0    Serviço  Facultativo           100% SMTR
# 222  SP553                    0    Serviço  Facultativo           100% SMTR
# 223  SV112                    4      Linha  Facultativo           100% SMTR
#
#      Faixa
# 0    00-03
# 1    00-03
# 2    00-03
# ...

# %%
df.to_csv('programacao_partidas_facul.csv', index=False, sep=';')
